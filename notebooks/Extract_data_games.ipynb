# %% [markdown]
# Sources
#
# #### Projet End-to-End (Pas NHL API)
# https://medium.com/coinmonks/4-718-using-machine-learning-to-bet-on-the-nhl-25d16649cd52
#
# #### Projet Live Feed (NHL API)
# ##### Utilise le live feed pour shot sur gardien
# https://towardsdatascience.com/nhl-analytics-with-python-6390c5d3206d
#
# #### Docu NHL API
# https://github.com/dword4/nhlapi
#
# Ancienne Doc:
# https://webcache.googleusercontent.com/search?q=cache:ILYmzDuxW70J:https://github.com/dword4/nhlapi+&cd=1&hl=en&ct=clnk&gl=ca

# %%
# Check Python Version
from platform import python_version
import pandas as pd
pd.set_option('display.max_columns', None)
print(python_version())
# Out:
# 3.6.5

# %% [markdown]
# ## import données Match

# %%
import requests  
from pandas.io.json import json_normalize

# Import données importantes par match
# À Faire: loop à travers les string pour scrape les données pour tous les jours de match
# https://statsapi.web.nhl.com/api/v1/schedule?date=2018-01-09
r = requests.get(url='https://statsapi.web.nhl.com/api/v1/schedule?date=2018-01-09')
data = r.json()

# mettre l'info dans un dataframe
df = json_normalize(data = data['dates'], record_path='games', meta=['date', 'totalGames'])
df.head(10)
# Out:
#        gamePk                               link gameType    season  \
# 0  2017020653  /api/v1/game/2017020653/feed/live        R  20172018
# 1  2017020654  /api/v1/game/2017020654/feed/live        R  20172018
# 2  2017020655  /api/v1/game/2017020655/feed/live        R  20172018
# 3  2017020656  /api/v1/game/2017020656/feed/live        R  20172018
# 4  2017020657  /api/v1/game/2017020657/feed/live        R  20172018
# 5  2017020658  /api/v1/game/2017020658/feed/live        R  20172018
# 6  2017020659  /api/v1/game/2017020659/feed/live        R  20172018
#
#                gameDate status.abstractGameState status.codedGameState  \
# 0  2018-01-10T00:00:00Z                    Final                     7
# 1  2018-01-10T00:00:00Z                    Final                     7
# 2  2018-01-10T00:30:00Z                    Final                     7
# 3  2018-01-10T00:30:00Z                    Final                     7
# 4  2018-01-10T01:00:00Z                    Final                     7
# 5  2018-01-10T01:00:00Z                    Final                     7
# 6  2018-01-10T01:00:00Z                    Final                     7
#
#   status.detailedState status.statusCode  status.startTimeTBD  \
# 0                Final                 7                False
# 1                Final                 7                False
# 2                Final                 7                False
# 3                Final                 7                False
# 4                Final                 7                False
# 5                Final                 7                False
# 6                Final                 7                False
#
#    teams.away.leagueRecord.wins  teams.away.leagueRecord.losses  \
# 0                            26                              11
# 1                            16                              21
# 2                            21                              15
# 3                            19                              15
# 4                            18                              18
# 5                            18                              23
# 6                            22                              16
#
#    teams.away.leagueRecord.ot teams.away.leagueRecord.type  teams.away.score  \
# 0                           7                       league                 7
# 1                           6                       league                 1
# 2                           6                       league                 8
# 3                           8                       league                 4
# 4                           6                       league                 7
# 5                           3                       league                 1
# 6                           4                       league                 3
#
#    teams.away.team.id teams.away.team.name teams.away.team.link  \
# 0                  52        Winnipeg Jets     /api/v1/teams/52
# 1                  23    Vancouver Canucks     /api/v1/teams/23
# 2                  16   Chicago Blackhawks     /api/v1/teams/16
# 3                  12  Carolina Hurricanes     /api/v1/teams/12
# 4                  13     Florida Panthers     /api/v1/teams/13
# 5                  22      Edmonton Oilers     /api/v1/teams/22
# 6                  20       Calgary Flames     /api/v1/teams/20
#
#    teams.home.leagueRecord.wins  teams.home.leagueRecord.losses  \
# 0                            10                              24
# 1                            27                              13
# 2                            14                              18
# 3                            31                               9
# 4                            26                              17
# 5                            25                              11
# 6                            22                              17
#
#    teams.home.leagueRecord.ot teams.home.leagueRecord.type  teams.home.score  \
# 0                           9                       league                 4
# 1                           3                       league                 3
# 2                           9                       league                 2
# 3                           3                       league                 5
# 4                           3                       league                 4
# 5                           6                       league                 2
# 6                           4                       league                 2
#
#    teams.home.team.id teams.home.team.name teams.home.team.link  venue.id  \
# 0                   7       Buffalo Sabres      /api/v1/teams/7    5039.0
# 1                  15  Washington Capitals     /api/v1/teams/15    5094.0
# 2                   9      Ottawa Senators      /api/v1/teams/9    5031.0
# 3                  14  Tampa Bay Lightning     /api/v1/teams/14    5017.0
# 4                  19      St. Louis Blues     /api/v1/teams/19       NaN
# 5                  18  Nashville Predators     /api/v1/teams/18    5030.0
# 6                  30       Minnesota Wild     /api/v1/teams/30    5098.0
#
#              venue.name           venue.link                     content.link  \
# 0        KeyBank Center  /api/v1/venues/5039  /api/v1/game/2017020653/content
# 1     Capital One Arena  /api/v1/venues/5094  /api/v1/game/2017020654/content
# 2  Canadian Tire Centre  /api/v1/venues/5031  /api/v1/game/2017020655/content
# 3          Amalie Arena  /api/v1/venues/5017  /api/v1/game/2017020656/content
# 4      Scottrade Center  /api/v1/venues/null  /api/v1/game/2017020657/content
# 5     Bridgestone Arena  /api/v1/venues/5030  /api/v1/game/2017020658/content
# 6    Xcel Energy Center  /api/v1/venues/5098  /api/v1/game/2017020659/content
#
#          date totalGames
# 0  2018-01-09          7
# 1  2018-01-09          7
# 2  2018-01-09          7
# 3  2018-01-09          7
# 4  2018-01-09          7
# 5  2018-01-09          7
# 6  2018-01-09          7

# %%
# Flatten Data simplement en Pandas Series ou en dictionnaire;

# %%
from itertools import chain, starmap

def flatten_json_iterative_solution(dictionary):
    """Flatten a nested json file"""

    def unpack(parent_key, parent_value):
        """Unpack one level of nesting in json file"""
        # Unpack one level only!!!
        
        if isinstance(parent_value, dict):
            for key, value in parent_value.items():
                temp1 = parent_key + '_' + key
                yield temp1, value
        elif isinstance(parent_value, list):
            i = 0 
            for value in parent_value:
                temp2 = parent_key + '_'+str(i) 
                i += 1
                yield temp2, value
        else:
            yield parent_key, parent_value    

            
    # Keep iterating until the termination condition is satisfied
    while True:
        # Keep unpacking the json file until all values are atomic elements (not dictionary or list)
        dictionary = dict(chain.from_iterable(starmap(unpack, dictionary.items())))
        # Terminate condition: not any value in the json file is dictionary or list
        if not any(isinstance(value, dict) for value in dictionary.values()) and \
           not any(isinstance(value, list) for value in dictionary.values()):
            break

    return dictionary

# %%
df = pd.Series(flatten_json_iterative_solution(data)).to_frame()
df.head(50)
# Out:
#                                                                                                 0
# copyright                                       NHL and the NHL Shield are registered trademar...
# totalItems                                                                                      7
# totalEvents                                                                                     0
# totalGames                                                                                      7
# totalMatches                                                                                    0
# wait                                                                                           10
# dates_0_date                                                                           2018-01-09
# dates_0_totalItems                                                                              7
# dates_0_totalEvents                                                                             0
# dates_0_totalGames                                                                              7
# dates_0_totalMatches                                                                            0
# dates_0_games_0_gamePk                                                                 2017020653
# dates_0_games_0_link                                            /api/v1/game/2017020653/feed/live
# dates_0_games_0_gameType                                                                        R
# dates_0_games_0_season                                                                   20172018
# dates_0_games_0_gameDate                                                     2018-01-10T00:00:00Z
# dates_0_games_0_status_abstractGameState                                                    Final
# dates_0_games_0_status_codedGameState                                                           7
# dates_0_games_0_status_detailedState                                                        Final
# dates_0_games_0_status_statusCode                                                               7
# dates_0_games_0_status_startTimeTBD                                                         False
# dates_0_games_0_teams_away_leagueRecord_wins                                                   26
# dates_0_games_0_teams_away_leagueRecord_losses                                                 11
# dates_0_games_0_teams_away_leagueRecord_ot                                                      7
# dates_0_games_0_teams_away_leagueRecord_type                                               league
# dates_0_games_0_teams_away_score                                                                7
# dates_0_games_0_teams_away_team_id                                                             52
# dates_0_games_0_teams_away_team_name                                                Winnipeg Jets
# dates_0_games_0_teams_away_team_link                                             /api/v1/teams/52
# dates_0_games_0_teams_home_leagueRecord_wins                                                   10
# dates_0_games_0_teams_home_leagueRecord_losses                                                 24
# dates_0_games_0_teams_home_leagueRecord_ot                                                      9
# dates_0_games_0_teams_home_leagueRecord_type                                               league
# dates_0_games_0_teams_home_score                                                                4
# dates_0_games_0_teams_home_team_id                                                              7
# dates_0_games_0_teams_home_team_name                                               Buffalo Sabres
# dates_0_games_0_teams_home_team_link                                              /api/v1/teams/7
# dates_0_games_0_venue_id                                                                     5039
# dates_0_games_0_venue_name                                                         KeyBank Center
# dates_0_games_0_venue_link                                                    /api/v1/venues/5039
# dates_0_games_0_content_link                                      /api/v1/game/2017020653/content
# dates_0_games_1_gamePk                                                                 2017020654
# dates_0_games_1_link                                            /api/v1/game/2017020654/feed/live
# dates_0_games_1_gameType                                                                        R
# dates_0_games_1_season                                                                   20172018
# dates_0_games_1_gameDate                                                     2018-01-10T00:00:00Z
# dates_0_games_1_status_abstractGameState                                                    Final
# dates_0_games_1_status_codedGameState                                                           7
# dates_0_games_1_status_detailedState                                                        Final
# dates_0_games_1_status_statusCode                                                               7

# %%
# Autre fonction qui va faire un flatten

def flatten_json(nested_json):
    """
        Flatten json object with nested keys into a single level.
        Args:
            nested_json: A nested json object.
        Returns:
            The flattened json object if successful, None otherwise.
    """
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(nested_json)
    return out

# %%
y = flatten_json(data)

# %%
y
# Out:
# {'copyright': 'NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. © NHL 2020. All Rights Reserved.',
#  'totalItems': 7,
#  'totalEvents': 0,
#  'totalGames': 7,
#  'totalMatches': 0,
#  'wait': 10,
#  'dates_0_date': '2018-01-09',
#  'dates_0_totalItems': 7,
#  'dates_0_totalEvents': 0,
#  'dates_0_totalGames': 7,
#  'dates_0_totalMatches': 0,
#  'dates_0_games_0_gamePk': 2017020653,
#  'dates_0_games_0_link': '/api/v1/game/2017020653/feed/live',
#  'dates_0_games_0_gameType': 'R',
#  'dates_0_games_0_season': '20172018',
#  'dates_0_games_0_gameDate': '2018-01-10T00:00:00Z',
#  'dates_0_games_0_status_abstractGameState': 'Final',
#  'dates_0_games_0_status_codedGameState': '7',
#  'dates_0_games_0_status_detailedState': 'Final',
#  'dates_0_games_0_status_statusCode': '7',
#  'dates_0_games_0_status_startTimeTBD': False,
#  'dates_0_games_0_teams_away_leagueRecord_wins': 26,
#  'dates_0_games_0_teams_away_leagueRecord_losses': 11,
#  'dates_0_games_0_teams_away_leagueRecord_ot': 7,
#  'dates_0_games_0_teams_away_leagueRecord_type': 'league',
#  'dates_0_games_0_teams_away_score': 7,
#  'dates_0_games_0_teams_away_team_id': 52,
#  'dates_0_games_0_teams_away_team_name': 'Winnipeg Jets',
#  'dates_0_games_0_teams_away_team_link': '/api/v1/teams/52',
#  'dates_0_games_0_teams_home_leagueRecord_wins': 10,
#  'dates_0_games_0_teams_home_leagueRecord_losses': 24,
#  'dates_0_games_0_teams_home_leagueRecord_ot': 9,
#  'dates_0_games_0_teams_home_leagueRecord_type': 'league',
#  'dates_0_games_0_teams_home_score': 4,
#  'dates_0_games_0_teams_home_team_id': 7,
#  'dates_0_games_0_teams_home_team_name': 'Buffalo Sabres',
#  'dates_0_games_0_teams_home_team_link': '/api/v1/teams/7',
#  'dates_0_games_0_venue_id': 5039,
#  'dates_0_games_0_venue_name': 'KeyBank Center',
#  'dates_0_games_0_venue_link': '/api/v1/venues/5039',
#  'dates_0_games_0_content_link': '/api/v1/game/2017020653/content',
#  'dates_0_games_1_gamePk': 2017020654,
#  'dates_0_games_1_link': '/api/v1/game/2017020654/feed/live',
#  'dates_0_games_1_gameType': 'R',
#  'dates_0_games_1_season': '20172018',
#  'dates_0_games_1_gameDate': '2018-01-10T00:00:00Z',
#  'dates_0_games_1_status_abstractGameState': 'Final',
#  'dates_0_games_1_status_codedGameState': '7',
#  'dates_0_games_1_status_detailedState': 'Final',
#  'dates_0_games_1_status_statusCode': '7',
#  'dates_0_games_1_status_startTimeTBD': False,
#  'dates_0_games_1_teams_away_leagueRecord_wins': 16,
#  'dates_0_games_1_teams_away_leagueRecord_losses': 21,
#  'dates_0_games_1_teams_away_leagueRecord_ot': 6,
#  'dates_0_games_1_teams_away_leagueRecord_type': 'league',
#  'dates_0_games_1_teams_away_score': 1,
#  'dates_0_games_1_teams_away_team_id': 23,
#  'dates_0_games_1_teams_away_team_name': 'Vancouver Canucks',
#  'dates_0_games_1_teams_away_team_link': '/api/v1/teams/23',
#  'dates_0_games_1_teams_home_leagueRecord_wins': 27,
#  'dates_0_games_1_teams_home_leagueRecord_losses': 13,
#  'dates_0_games_1_teams_home_leagueRecord_ot': 3,
#  'dates_0_games_1_teams_home_leagueRecord_type': 'league',
#  'dates_0_games_1_teams_home_score': 3,
#  'dates_0_games_1_teams_home_team_id': 15,
#  'dates_0_games_1_teams_home_team_name': 'Washington Capitals',
#  'dates_0_games_1_teams_home_team_link': '/api/v1/teams/15',
#  'dates_0_games_1_venue_id': 5094,
#  'dates_0_games_1_venue_name': 'Capital One Arena',
#  'dates_0_games_1_venue_link': '/api/v1/venues/5094',
#  'dates_0_games_1_content_link': '/api/v1/game/2017020654/content',
#  'dates_0_games_2_gamePk': 2017020655,
#  'dates_0_games_2_link': '/api/v1/game/2017020655/feed/live',
#  'dates_0_games_2_gameType': 'R',
#  'dates_0_games_2_season': '20172018',
#  'dates_0_games_2_gameDate': '2018-01-10T00:30:00Z',
#  'dates_0_games_2_status_abstractGameState': 'Final',
#  'dates_0_games_2_status_codedGameState': '7',
#  'dates_0_games_2_status_detailedState': 'Final',
#  'dates_0_games_2_status_statusCode': '7',
#  'dates_0_games_2_status_startTimeTBD': False,
#  'dates_0_games_2_teams_away_leagueRecord_wins': 21,
#  'dates_0_games_2_teams_away_leagueRecord_losses': 15,
#  'dates_0_games_2_teams_away_leagueRecord_ot': 6,
#  'dates_0_games_2_teams_away_leagueRecord_type': 'league',
#  'dates_0_games_2_teams_away_score': 8,
#  'dates_0_games_2_teams_away_team_id': 16,
#  'dates_0_games_2_teams_away_team_name': 'Chicago Blackhawks',
#  'dates_0_games_2_teams_away_team_link': '/api/v1/teams/16',
#  'dates_0_games_2_teams_home_leagueRecord_wins': 14,
#  'dates_0_games_2_teams_home_leagueRecord_losses': 18,
#  'dates_0_games_2_teams_home_leagueRecord_ot': 9,
#  'dates_0_games_2_teams_home_leagueRecord_type': 'league',
#  'dates_0_games_2_teams_home_score': 2,
#  'dates_0_games_2_teams_home_team_id': 9,
#  'dates_0_games_2_teams_home_team_name': 'Ottawa Senators',
#  'dates_0_games_2_teams_home_team_link': '/api/v1/teams/9',
#  'dates_0_games_2_venue_id': 5031,
#  'dates_0_games_2_venue_name': 'Canadian Tire Centre',
#  'dates_0_games_2_venue_link': '/api/v1/venues/5031',
#  'dates_0_games_2_content_link': '/api/v1/game/2017020655/content',
#  'dates_0_games_3_gamePk': 2017020656,
#  'dates_0_games_3_link': '/api/v1/game/2017020656/feed/live',
#  'dates_0_games_3_gameType': 'R',
#  'dates_0_games_3_season': '20172018',
#  'dates_0_games_3_gameDate': '2018-01-10T00:30:00Z',
#  'dates_0_games_3_status_abstractGameState': 'Final',
#  'dates_0_games_3_status_codedGameState': '7',
#  'dates_0_games_3_status_detailedState': 'Final',
#  'dates_0_games_3_status_statusCode': '7',
#  'dates_0_games_3_status_startTimeTBD': False,
#  'dates_0_games_3_teams_away_leagueRecord_wins': 19,
#  'dates_0_games_3_teams_away_leagueRecord_losses': 15,
#  'dates_0_games_3_teams_away_leagueRecord_ot': 8,
#  'dates_0_games_3_teams_away_leagueRecord_type': 'league',
#  'dates_0_games_3_teams_away_score': 4,
#  'dates_0_games_3_teams_away_team_id': 12,
#  'dates_0_games_3_teams_away_team_name': 'Carolina Hurricanes',
#  'dates_0_games_3_teams_away_team_link': '/api/v1/teams/12',
#  'dates_0_games_3_teams_home_leagueRecord_wins': 31,
#  'dates_0_games_3_teams_home_leagueRecord_losses': 9,
#  'dates_0_games_3_teams_home_leagueRecord_ot': 3,
#  'dates_0_games_3_teams_home_leagueRecord_type': 'league',
#  'dates_0_games_3_teams_home_score': 5,
#  'dates_0_games_3_teams_home_team_id': 14,
#  'dates_0_games_3_teams_home_team_name': 'Tampa Bay Lightning',
#  'dates_0_games_3_teams_home_team_link': '/api/v1/teams/14',
#  'dates_0_games_3_venue_id': 5017,
#  'dates_0_games_3_venue_name': 'Amalie Arena',
#  'dates_0_games_3_venue_link': '/api/v1/venues/5017',
#  'dates_0_games_3_content_link': '/api/v1/game/2017020656/content',
#  'dates_0_games_4_gamePk': 2017020657,
#  'dates_0_games_4_link': '/api/v1/game/2017020657/feed/live',
#  'dates_0_games_4_gameType': 'R',
#  'dates_0_games_4_season': '20172018',
#  'dates_0_games_4_gameDate': '2018-01-10T01:00:00Z',
#  'dates_0_games_4_status_abstractGameState': 'Final',
#  'dates_0_games_4_status_codedGameState': '7',
#  'dates_0_games_4_status_detailedState': 'Final',
#  'dates_0_games_4_status_statusCode': '7',
#  'dates_0_games_4_status_startTimeTBD': False,
#  'dates_0_games_4_teams_away_leagueRecord_wins': 18,
#  'dates_0_games_4_teams_away_leagueRecord_losses': 18,
#  'dates_0_games_4_teams_away_leagueRecord_ot': 6,
#  'dates_0_games_4_teams_away_leagueRecord_type': 'league',
#  'dates_0_games_4_teams_away_score': 7,
#  'dates_0_games_4_teams_away_team_id': 13,
#  'dates_0_games_4_teams_away_team_name': 'Florida Panthers',
#  'dates_0_games_4_teams_away_team_link': '/api/v1/teams/13',
#  'dates_0_games_4_teams_home_leagueRecord_wins': 26,
#  'dates_0_games_4_teams_home_leagueRecord_losses': 17,
#  'dates_0_games_4_teams_home_leagueRecord_ot': 3,
#  'dates_0_games_4_teams_home_leagueRecord_type': 'league',
#  'dates_0_games_4_teams_home_score': 4,
#  'dates_0_games_4_teams_home_team_id': 19,
#  'dates_0_games_4_teams_home_team_name': 'St. Louis Blues',
#  'dates_0_games_4_teams_home_team_link': '/api/v1/teams/19',
#  'dates_0_games_4_venue_name': 'Scottrade Center',
#  'dates_0_games_4_venue_link': '/api/v1/venues/null',
#  'dates_0_games_4_content_link': '/api/v1/game/2017020657/content',
#  'dates_0_games_5_gamePk': 2017020658,
#  'dates_0_games_5_link': '/api/v1/game/2017020658/feed/live',
#  'dates_0_games_5_gameType': 'R',
#  'dates_0_games_5_season': '20172018',
#  'dates_0_games_5_gameDate': '2018-01-10T01:00:00Z',
#  'dates_0_games_5_status_abstractGameState': 'Final',
#  'dates_0_games_5_status_codedGameState': '7',
#  'dates_0_games_5_status_detailedState': 'Final',
#  'dates_0_games_5_status_statusCode': '7',
#  'dates_0_games_5_status_startTimeTBD': False,
#  'dates_0_games_5_teams_away_leagueRecord_wins': 18,
#  'dates_0_games_5_teams_away_leagueRecord_losses': 23,
#  'dates_0_games_5_teams_away_leagueRecord_ot': 3,
#  'dates_0_games_5_teams_away_leagueRecord_type': 'league',
#  'dates_0_games_5_teams_away_score': 1,
#  'dates_0_games_5_teams_away_team_id': 22,
#  'dates_0_games_5_teams_away_team_name': 'Edmonton Oilers',
#  'dates_0_games_5_teams_away_team_link': '/api/v1/teams/22',
#  'dates_0_games_5_teams_home_leagueRecord_wins': 25,
#  'dates_0_games_5_teams_home_leagueRecord_losses': 11,
#  'dates_0_games_5_teams_home_leagueRecord_ot': 6,
#  'dates_0_games_5_teams_home_leagueRecord_type': 'league',
#  'dates_0_games_5_teams_home_score': 2,
#  'dates_0_games_5_teams_home_team_id': 18,
#  'dates_0_games_5_teams_home_team_name': 'Nashville Predators',
#  'dates_0_games_5_teams_home_team_link': '/api/v1/teams/18',
#  'dates_0_games_5_venue_id': 5030,
#  'dates_0_games_5_venue_name': 'Bridgestone Arena',
#  'dates_0_games_5_venue_link': '/api/v1/venues/5030',
#  'dates_0_games_5_content_link': '/api/v1/game/2017020658/content',
#  'dates_0_games_6_gamePk': 2017020659,
#  'dates_0_games_6_link': '/api/v1/game/2017020659/feed/live',
#  'dates_0_games_6_gameType': 'R',
#  'dates_0_games_6_season': '20172018',
#  'dates_0_games_6_gameDate': '2018-01-10T01:00:00Z',
#  'dates_0_games_6_status_abstractGameState': 'Final',
#  'dates_0_games_6_status_codedGameState': '7',
#  'dates_0_games_6_status_detailedState': 'Final',
#  'dates_0_games_6_status_statusCode': '7',
#  'dates_0_games_6_status_startTimeTBD': False,
#  'dates_0_games_6_teams_away_leagueRecord_wins': 22,
#  'dates_0_games_6_teams_away_leagueRecord_losses': 16,
#  'dates_0_games_6_teams_away_leagueRecord_ot': 4,
#  'dates_0_games_6_teams_away_leagueRecord_type': 'league',
#  'dates_0_games_6_teams_away_score': 3,
#  'dates_0_games_6_teams_away_team_id': 20,
#  'dates_0_games_6_teams_away_team_name': 'Calgary Flames',
#  'dates_0_games_6_teams_away_team_link': '/api/v1/teams/20',
#  'dates_0_games_6_teams_home_leagueRecord_wins': 22,
#  'dates_0_games_6_teams_home_leagueRecord_losses': 17,
#  'dates_0_games_6_teams_home_leagueRecord_ot': 4,
#  'dates_0_games_6_teams_home_leagueRecord_type': 'league',
#  'dates_0_games_6_teams_home_score': 2,
#  'dates_0_games_6_teams_home_team_id': 30,
#  'dates_0_games_6_teams_home_team_name': 'Minnesota Wild',
#  'dates_0_games_6_teams_home_team_link': '/api/v1/teams/30',
#  'dates_0_games_6_venue_id': 5098,
#  'dates_0_games_6_venue_name': 'Xcel Energy Center',
#  'dates_0_games_6_venue_link': '/api/v1/venues/5098',
#  'dates_0_games_6_content_link': '/api/v1/game/2017020659/content'}

# %%
exemple = json_normalize(data = data)
exemple
# Out:
#                                            copyright  totalItems  totalEvents  \
# 0  NHL and the NHL Shield are registered trademar...           7            0
#
#    totalGames  totalMatches  wait  \
# 0           7             0    10
#
#                                                dates
# 0  [{'date': '2018-01-09', 'totalItems': 7, 'tota...
