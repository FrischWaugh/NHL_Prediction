# %%
# Programme pour importer les equipes

import requests
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize

# %%
url = 'https://statsapi.web.nhl.com/api/v1/teams'

# %%
r = requests.get(url)

# %%
json_data = r.json()

# %%
r
# Out:
# <Response [200]>

# %%
type(json_data)
# Out:
# dict

# %%
print(json_data.keys())
# Out:
# dict_keys(['copyright', 'teams'])

# %%
print(r.text)
# Out:
# {
#   "copyright" : "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. © NHL 2019. All Rights Reserved.",
#   "teams" : [ {
#     "id" : 1,
#     "name" : "New Jersey Devils",
#     "link" : "/api/v1/teams/1",
#     "venue" : {
#       "name" : "Prudential Center",
#       "link" : "/api/v1/venues/null",
#       "city" : "Newark",
#       "timeZone" : {
#         "id" : "America/New_York",
#         "offset" : -5,
#         "tz" : "EST"
#       }
#     },
#     "abbreviation" : "NJD",
#     "teamName" : "Devils",
#     "locationName" : "New Jersey",
#     "firstYearOfPlay" : "1982",
#     "division" : {
#       "id" : 18,
#       "name" : "Metropolitan",
#       "nameShort" : "Metro",
#       "link" : "/api/v1/divisions/18",
#       "abbreviation" : "M"
#     },
#     "conference" : {
#       "id" : 6,
#       "name" : "Eastern",
#       "link" : "/api/v1/conferences/6"
#     },
# ...

# %%
teams = json_normalize(json_data['teams'], sep = "_")

# %%
print(list(teams))
# Out:
# ['id', 'name', 'link', 'abbreviation', 'teamName', 'locationName', 'firstYearOfPlay', 'shortName', 'officialSiteUrl', 'franchiseId', 'active', 'venue_name', 'venue_link', 'venue_city', 'venue_timeZone_id', 'venue_timeZone_offset', 'venue_timeZone_tz', 'division_id', 'division_name', 'division_nameShort', 'division_link', 'division_abbreviation', 'conference_id', 'conference_name', 'conference_link', 'franchise_franchiseId', 'franchise_teamName', 'franchise_link', 'venue_id']

# %%
teams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 29 columns):
# id                       31 non-null int64
# name                     31 non-null object
# link                     31 non-null object
# abbreviation             31 non-null object
# teamName                 31 non-null object
# locationName             31 non-null object
# firstYearOfPlay          31 non-null object
# shortName                31 non-null object
# officialSiteUrl          31 non-null object
# franchiseId              31 non-null int64
# active                   31 non-null bool
# venue_name               31 non-null object
# venue_link               31 non-null object
# venue_city               31 non-null object
# venue_timeZone_id        31 non-null object
# venue_timeZone_offset    31 non-null int64
# venue_timeZone_tz        31 non-null object
# division_id              31 non-null int64
# division_name            31 non-null object
# ...

# %%
teams_norm
# Out:
#     id                   name              link abbreviation        teamName  \
# 0    2     New York Islanders   /api/v1/teams/2          NYI       Islanders
# 1    3       New York Rangers   /api/v1/teams/3          NYR         Rangers
# 2    4    Philadelphia Flyers   /api/v1/teams/4          PHI          Flyers
# 3    5    Pittsburgh Penguins   /api/v1/teams/5          PIT        Penguins
# 4    6          Boston Bruins   /api/v1/teams/6          BOS          Bruins
# 5    7         Buffalo Sabres   /api/v1/teams/7          BUF          Sabres
# 6    8     Montréal Canadiens   /api/v1/teams/8          MTL       Canadiens
# 7    9        Ottawa Senators   /api/v1/teams/9          OTT        Senators
# 8   10    Toronto Maple Leafs  /api/v1/teams/10          TOR     Maple Leafs
# 9   12    Carolina Hurricanes  /api/v1/teams/12          CAR      Hurricanes
# 10  13       Florida Panthers  /api/v1/teams/13          FLA        Panthers
# ...

# %%
teams.to_pickle('../../data/teams.csv')
