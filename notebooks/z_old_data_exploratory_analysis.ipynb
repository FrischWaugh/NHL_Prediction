# %%
# Import the important packages
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
def create_lag(df, p, sortList, partList, lagList):
    """
    Cette fonction prend comme intrant un df, une liste de variables pour lesquelles il faut
    creer des valeurs retardees, le nombre de retard, les variables sur lesquelles il faut sort,
    les variables de partition et la liste de varibles pour lesquelles on veut des valeurs retardees.
    La fonction retourne un df augmente des variables retardees
    """
    df = df.sort_values(by=sortList)
    
    for feature in lagList:
        for i in range(p):
            df['{}.L{}'.format(feature,i+1)] = df.groupby(partList)[feature].shift(i+1)
    
    return df

# %%
# Load the raw data
gamesdf = pd.read_csv('../../data/games.csv')

# %% [markdown]
# #### Inspect the data

# %%
gamesdf.head()
# Out:
#    Unnamed: 0  away.teamStats.teamSkaterStats.blocked  \
# 0           0                                       9
# 1           1                                       8
# 2           2                                      18
# 3           3                                       9
# 4           4                                       6
#
#    away.teamStats.teamSkaterStats.faceOffWinPercentage  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    away.teamStats.teamSkaterStats.giveaways  \
# 0                                        22
# 1                                         7
# 2                                        15
# 3                                        13
# 4                                         3
#
#    away.teamStats.teamSkaterStats.goals  away.teamStats.teamSkaterStats.hits  \
# 0                                     1                                   16
# 1                                     3                                   18
# 2                                     3                                   20
# 3                                     2                                   31
# 4                                     2                                    9
#
#    away.teamStats.teamSkaterStats.pim  \
# 0                                   4
# 1                                  13
# 2                                   8
# 3                                  63
# 4                                   8
#
#    away.teamStats.teamSkaterStats.powerPlayGoals  \
# 0                                            0.0
# 1                                            0.0
# 2                                            0.0
# 3                                            1.0
# 4                                            0.0
#
#    away.teamStats.teamSkaterStats.powerPlayOpportunities  \
# 0                                                3.0
# 1                                                2.0
# 2                                                5.0
# 3                                                2.0
# 4                                                2.0
#
#    away.teamStats.teamSkaterStats.powerPlayPercentage  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
# 3                                               50.0
# 4                                                0.0
#
#    away.teamStats.teamSkaterStats.shots  \
# 0                                  25.0
# 1                                  34.0
# 2                                  33.0
# 3                                  34.0
# 4                                  33.0
#
#    away.teamStats.teamSkaterStats.takeaways                     content.link  \
# 0                                         4  /api/v1/game/2007020584/content
# 1                                         3  /api/v1/game/2007020585/content
# 2                                         8  /api/v1/game/2007020586/content
# 3                                         7  /api/v1/game/2007020587/content
# 4                                         7  /api/v1/game/2007020588/content
#
#          date              gameDate      gameID      gamePk gameType  \
# 0  2008-01-01  2008-01-01T18:00:00Z  2007020584  2007020584        R
# 1  2008-01-01  2008-01-01T21:00:00Z  2007020585  2007020585        R
# 2  2008-01-01  2008-01-02T00:30:00Z  2007020586  2007020586        R
# 3  2008-01-01  2008-01-02T03:30:00Z  2007020587  2007020587        R
# 4  2008-01-02  2008-01-03T00:00:00Z  2007020588  2007020588        R
#
#    home.teamStats.teamSkaterStats.blocked  \
# 0                                      10
# 1                                      17
# 2                                      24
# 3                                      12
# 4                                       8
#
#    home.teamStats.teamSkaterStats.faceOffWinPercentage  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    home.teamStats.teamSkaterStats.giveaways  \
# 0                                        17
# 1                                        10
# 2                                        19
# 3                                        11
# 4                                         6
#
#    home.teamStats.teamSkaterStats.goals  home.teamStats.teamSkaterStats.hits  \
# 0                                     1                                   26
# 1                                     6                                   14
# 2                                     3                                   29
# 3                                     9                                   17
# 4                                     3                                    6
#
#    home.teamStats.teamSkaterStats.pim  \
# 0                                   6
# 1                                  11
# 2                                  14
# 3                                  31
# 4                                   6
#
#    home.teamStats.teamSkaterStats.powerPlayGoals  \
# 0                                            0.0
# 1                                            1.0
# 2                                            0.0
# 3                                            5.0
# 4                                            1.0
#
#    home.teamStats.teamSkaterStats.powerPlayOpportunities  \
# 0                                                2.0
# 1                                                3.0
# 2                                                2.0
# 3                                                7.0
# 4                                                3.0
#
#    home.teamStats.teamSkaterStats.powerPlayPercentage  \
# 0                                                0.0
# 1                                               33.3
# 2                                                0.0
# 3                                               71.4
# 4                                               33.3
#
#    home.teamStats.teamSkaterStats.shots  \
# 0                                  37.0
# 1                                  26.0
# 2                                  29.0
# 3                                  26.0
# 4                                  27.0
#
#    home.teamStats.teamSkaterStats.takeaways  \
# 0                                         8
# 1                                         8
# 2                                         4
# 3                                         4
# 4                                         9
#
#                                 link    season status.abstractGameState  \
# 0  /api/v1/game/2007020584/feed/live  20072008                    Final
# 1  /api/v1/game/2007020585/feed/live  20072008                    Final
# 2  /api/v1/game/2007020586/feed/live  20072008                    Final
# 3  /api/v1/game/2007020587/feed/live  20072008                    Final
# 4  /api/v1/game/2007020588/feed/live  20072008                    Final
#
#    status.codedGameState status.detailedState  status.startTimeTBD  \
# 0                      7                Final                False
# 1                      7                Final                False
# 2                      7                Final                False
# 3                      7                Final                False
# 4                      7                Final                False
#
#    status.statusCode  teams.away.leagueRecord.losses  \
# 0                  7                              16
# 1                  7                              10
# 2                  7                              21
# 3                  7                              16
# 4                  7                              19
#
#    teams.away.leagueRecord.ot teams.away.leagueRecord.type  \
# 0                         2.0                       league
# 1                         4.0                       league
# 2                         4.0                       league
# 3                         3.0                       league
# 4                         3.0                       league
#
#    teams.away.leagueRecord.wins  teams.away.score  teams.away.team.id  \
# 0                            21                 2                   5
# 1                            25                 3                   9
# 2                            15                 3                  14
# 3                            19                 2                  16
# 4                            18                 2                  13
#
#   teams.away.team.link teams.away.team.name  teams.home.leagueRecord.losses  \
# 0      /api/v1/teams/5  Pittsburgh Penguins                              16
# 1      /api/v1/teams/9      Ottawa Senators                              19
# 2     /api/v1/teams/14  Tampa Bay Lightning                              16
# 3     /api/v1/teams/16   Chicago Blackhawks                              24
# 4     /api/v1/teams/13     Florida Panthers                              14
#
#    teams.home.leagueRecord.ot teams.home.leagueRecord.type  \
# 0                         3.0                       league
# 1                         5.0                       league
# 2                         8.0                       league
# 3                         2.0                       league
# 4                         3.0                       league
#
#    teams.home.leagueRecord.wins  teams.home.score  teams.home.team.id  \
# 0                            19                 1                   7
# 1                            16                 6                  15
# 2                            16                 4                  10
# 3                            15                 9                  26
# 4                            22                 3                   1
#
#   teams.home.team.link teams.home.team.name  venue.id           venue.link  \
# 0      /api/v1/teams/7       Buffalo Sabres       NaN  /api/v1/venues/null
# 1     /api/v1/teams/15  Washington Capitals       NaN  /api/v1/venues/null
# 2     /api/v1/teams/10  Toronto Maple Leafs    5015.0  /api/v1/venues/5015
# 3     /api/v1/teams/26    Los Angeles Kings    5081.0  /api/v1/venues/5081
# 4      /api/v1/teams/1    New Jersey Devils       NaN  /api/v1/venues/null
#
#              venue.name
# 0  Ralph Wilson Stadium
# 1        Verizon Center
# 2     Air Canada Centre
# 3        STAPLES Center
# 4     Prudential Center

# %%
gamesdf.describe(include='all')
# Out:
#           Unnamed: 0  away.teamStats.teamSkaterStats.blocked  \
# count   11529.000000                            11529.000000
# unique           NaN                                     NaN
# top              NaN                                     NaN
# freq             NaN                                     NaN
# mean     5764.000000                               13.780293
# std      3328.279961                                5.681997
# min         0.000000                                0.000000
# 25%      2882.000000                               10.000000
# 50%      5764.000000                               14.000000
# 75%      8646.000000                               17.000000
# max     11528.000000                               46.000000
#
#         away.teamStats.teamSkaterStats.faceOffWinPercentage  \
# count                                         8003.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            47.521354
# std                                              9.373603
# min                                              0.000000
# 25%                                             43.300000
# 50%                                             48.100000
# 75%                                             53.000000
# max                                             72.500000
#
#         away.teamStats.teamSkaterStats.giveaways  \
# count                               11529.000000
# unique                                       NaN
# top                                          NaN
# freq                                         NaN
# mean                                    6.530402
# std                                     4.346619
# min                                     0.000000
# 25%                                     3.000000
# 50%                                     6.000000
# 75%                                     9.000000
# max                                    37.000000
#
#         away.teamStats.teamSkaterStats.goals  \
# count                           11529.000000
# unique                                   NaN
# top                                      NaN
# freq                                     NaN
# mean                                2.519906
# std                                 1.603304
# min                                 0.000000
# 25%                                 1.000000
# 50%                                 2.000000
# 75%                                 4.000000
# max                                17.000000
#
#         away.teamStats.teamSkaterStats.hits  \
# count                          11529.000000
# unique                                  NaN
# top                                     NaN
# freq                                    NaN
# mean                              21.578107
# std                                9.295957
# min                                0.000000
# 25%                               16.000000
# 50%                               21.000000
# 75%                               27.000000
# max                               69.000000
#
#         away.teamStats.teamSkaterStats.pim  \
# count                         11529.000000
# unique                                 NaN
# top                                    NaN
# freq                                   NaN
# mean                             11.937462
# std                               9.284621
# min                               0.000000
# 25%                               6.000000
# 50%                              10.000000
# 75%                              15.000000
# max                             163.000000
#
#         away.teamStats.teamSkaterStats.powerPlayGoals  \
# count                                    11529.000000
# unique                                            NaN
# top                                               NaN
# freq                                              NaN
# mean                                         0.569694
# std                                          0.752872
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          1.000000
# max                                          5.000000
#
#         away.teamStats.teamSkaterStats.powerPlayOpportunities  \
# count                                        11529.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             3.249458
# std                                              1.719751
# min                                              0.000000
# 25%                                              2.000000
# 50%                                              3.000000
# 75%                                              4.000000
# max                                             11.000000
#
#         away.teamStats.teamSkaterStats.powerPlayPercentage  \
# count                                        11529.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            16.698586
# std                                             23.276408
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                             33.300000
# max                                            100.000000
#
#         away.teamStats.teamSkaterStats.shots  \
# count                           11371.000000
# unique                                   NaN
# top                                      NaN
# freq                                     NaN
# mean                               28.611820
# std                                 7.298044
# min                                 0.000000
# 25%                                24.000000
# 50%                                28.000000
# 75%                                33.000000
# max                                62.000000
#
#         away.teamStats.teamSkaterStats.takeaways  \
# count                               11529.000000
# unique                                       NaN
# top                                          NaN
# freq                                         NaN
# mean                                    5.557897
# std                                     3.422681
# min                                     0.000000
# 25%                                     3.000000
# 50%                                     5.000000
# 75%                                     8.000000
# max                                    27.000000
#
#                            content.link        date              gameDate  \
# count                             11529       11529                 11529
# unique                            11529        1963                  7277
# top     /api/v1/game/2009021170/content  2009-10-24  2015-11-15T00:00:00Z
# freq                                  1          15                     9
# mean                                NaN         NaN                   NaN
# std                                 NaN         NaN                   NaN
# min                                 NaN         NaN                   NaN
# 25%                                 NaN         NaN                   NaN
# 50%                                 NaN         NaN                   NaN
# 75%                                 NaN         NaN                   NaN
# max                                 NaN         NaN                   NaN
#
#               gameID        gamePk gameType  \
# count   1.152900e+04  1.152900e+04    11529
# unique           NaN           NaN        4
# top              NaN           NaN        R
# freq             NaN           NaN     9977
# mean    2.011206e+09  2.011206e+09      NaN
# std     2.525422e+06  2.525422e+06      NaN
# min     2.007021e+09  2.007021e+09      NaN
# 25%     2.009021e+09  2.009021e+09      NaN
# 50%     2.011021e+09  2.011021e+09      NaN
# 75%     2.013030e+09  2.013030e+09      NaN
# max     2.015041e+09  2.015041e+09      NaN
#
#         home.teamStats.teamSkaterStats.blocked  \
# count                             11529.000000
# unique                                     NaN
# top                                        NaN
# freq                                       NaN
# mean                                 13.148322
# std                                   5.584522
# min                                   0.000000
# 25%                                  10.000000
# 50%                                  13.000000
# 75%                                  17.000000
# max                                  40.000000
#
#         home.teamStats.teamSkaterStats.faceOffWinPercentage  \
# count                                         8003.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            50.791778
# std                                              9.663431
# min                                              0.000000
# 25%                                             46.600000
# 50%                                             51.600000
# 75%                                             56.400000
# max                                             78.200000
#
#         home.teamStats.teamSkaterStats.giveaways  \
# count                               11529.000000
# unique                                       NaN
# top                                          NaN
# freq                                         NaN
# mean                                    9.211727
# std                                     5.166202
# min                                     0.000000
# 25%                                     6.000000
# 50%                                     9.000000
# 75%                                    12.000000
# max                                    41.000000
#
#         home.teamStats.teamSkaterStats.goals  \
# count                           11529.000000
# unique                                   NaN
# top                                      NaN
# freq                                     NaN
# mean                                2.795386
# std                                 1.693210
# min                                 0.000000
# 25%                                 2.000000
# 50%                                 3.000000
# 75%                                 4.000000
# max                                12.000000
#
#         home.teamStats.teamSkaterStats.hits  \
# count                          11529.000000
# unique                                  NaN
# top                                     NaN
# freq                                    NaN
# mean                              23.581577
# std                                9.518880
# min                                0.000000
# 25%                               18.000000
# 50%                               23.000000
# 75%                               29.000000
# max                               88.000000
#
#         home.teamStats.teamSkaterStats.pim  \
# count                         11529.000000
# unique                                 NaN
# top                                    NaN
# freq                                   NaN
# mean                             11.221008
# std                               8.893516
# min                               0.000000
# 25%                               6.000000
# 50%                               9.000000
# 75%                              14.000000
# max                             183.000000
#
#         home.teamStats.teamSkaterStats.powerPlayGoals  \
# count                                    11529.000000
# unique                                            NaN
# top                                               NaN
# freq                                              NaN
# mean                                         0.669616
# std                                          0.817093
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          1.000000
# max                                          6.000000
#
#         home.teamStats.teamSkaterStats.powerPlayOpportunities  \
# count                                        11529.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             3.557811
# std                                              1.831128
# min                                              0.000000
# 25%                                              2.000000
# 50%                                              3.000000
# 75%                                              5.000000
# max                                             13.000000
#
#         home.teamStats.teamSkaterStats.powerPlayPercentage  \
# count                                        11529.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            17.795585
# std                                             22.759386
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                             33.300000
# max                                            100.000000
#
#         home.teamStats.teamSkaterStats.shots  \
# count                           11371.000000
# unique                                   NaN
# top                                      NaN
# freq                                     NaN
# mean                               30.501539
# std                                 7.631329
# min                                 0.000000
# 25%                                26.000000
# 50%                                30.000000
# 75%                                35.000000
# max                                63.000000
#
#         home.teamStats.teamSkaterStats.takeaways  \
# count                               11529.000000
# unique                                       NaN
# top                                          NaN
# freq                                         NaN
# mean                                    7.486946
# std                                     4.223873
# min                                     0.000000
# 25%                                     5.000000
# 50%                                     7.000000
# 75%                                    10.000000
# max                                    32.000000
#
#                                      link        season  \
# count                               11529  1.152900e+04
# unique                              11529           NaN
# top     /api/v1/game/2008020795/feed/live           NaN
# freq                                    1           NaN
# mean                                  NaN  2.011387e+07
# std                                   NaN  2.525788e+04
# min                                   NaN  2.007201e+07
# 25%                                   NaN  2.009201e+07
# 50%                                   NaN  2.011201e+07
# 75%                                   NaN  2.013201e+07
# max                                   NaN  2.015202e+07
#
#        status.abstractGameState  status.codedGameState status.detailedState  \
# count                     11529           11529.000000                11529
# unique                        1                    NaN                    1
# top                       Final                    NaN                Final
# freq                      11529                    NaN                11529
# mean                        NaN               6.934513                  NaN
# std                         NaN               0.247394                  NaN
# min                         NaN               6.000000                  NaN
# 25%                         NaN               7.000000                  NaN
# 50%                         NaN               7.000000                  NaN
# 75%                         NaN               7.000000                  NaN
# max                         NaN               7.000000                  NaN
#
#        status.startTimeTBD  status.statusCode  teams.away.leagueRecord.losses  \
# count                11529       11529.000000                    11529.000000
# unique                   1                NaN                             NaN
# top                  False                NaN                             NaN
# freq                 11529                NaN                             NaN
# mean                   NaN           6.934513                       13.967040
# std                    NaN           0.247394                       10.468383
# min                    NaN           6.000000                        0.000000
# 25%                    NaN           7.000000                        5.000000
# 50%                    NaN           7.000000                       13.000000
# 75%                    NaN           7.000000                       22.000000
# max                    NaN           7.000000                       51.000000
#
#         teams.away.leagueRecord.ot teams.away.leagueRecord.type  \
# count                 10698.000000                        11529
# unique                         NaN                            1
# top                            NaN                       league
# freq                           NaN                        11529
# mean                      4.569452                          NaN
# std                       3.545467                          NaN
# min                       0.000000                          NaN
# 25%                       1.000000                          NaN
# 50%                       4.000000                          NaN
# 75%                       7.000000                          NaN
# max                      18.000000                          NaN
#
#         teams.away.leagueRecord.wins  teams.away.score  teams.away.team.id  \
# count                   11529.000000      11529.000000        11529.000000
# unique                           NaN               NaN                 NaN
# top                              NaN               NaN                 NaN
# freq                             NaN               NaN                 NaN
# mean                       18.279122          2.635875           16.432908
# std                        13.350438          1.591131           10.566560
# min                         0.000000          0.000000            1.000000
# 25%                         6.000000          1.000000            8.000000
# 50%                        17.000000          3.000000           16.000000
# 75%                        29.000000          4.000000           24.000000
# max                        56.000000         17.000000           98.000000
#
#        teams.away.team.link teams.away.team.name  \
# count                 11529                11529
# unique                   39                   39
# top        /api/v1/teams/16   Chicago Blackhawks
# freq                    424                  424
# mean                    NaN                  NaN
# std                     NaN                  NaN
# min                     NaN                  NaN
# 25%                     NaN                  NaN
# 50%                     NaN                  NaN
# 75%                     NaN                  NaN
# max                     NaN                  NaN
#
#         teams.home.leagueRecord.losses  teams.home.leagueRecord.ot  \
# count                     11529.000000                10698.000000
# unique                             NaN                         NaN
# top                                NaN                         NaN
# freq                               NaN                         NaN
# mean                         13.917859                    4.562815
# std                          10.460167                    3.550887
# min                           0.000000                    0.000000
# 25%                           4.000000                    1.000000
# 50%                          13.000000                    4.000000
# 75%                          22.000000                    7.000000
# max                          51.000000                   18.000000
#
#        teams.home.leagueRecord.type  teams.home.leagueRecord.wins  \
# count                         11529                  11529.000000
# unique                            1                           NaN
# top                          league                           NaN
# freq                          11529                           NaN
# mean                            NaN                     18.320583
# std                             NaN                     13.348831
# min                             NaN                      0.000000
# 25%                             NaN                      6.000000
# 50%                             NaN                     17.000000
# 75%                             NaN                     29.000000
# max                             NaN                     56.000000
#
#         teams.home.score  teams.home.team.id teams.home.team.link  \
# count       11529.000000        11529.000000                11529
# unique               NaN                 NaN                   62
# top                  NaN                 NaN      /api/v1/teams/5
# freq                 NaN                 NaN                  418
# mean            2.913869           28.701188                  NaN
# std             1.662374          264.256300                  NaN
# min             0.000000            1.000000                  NaN
# 25%             2.000000            8.000000                  NaN
# 50%             3.000000           16.000000                  NaN
# 75%             4.000000           24.000000                  NaN
# max            12.000000         7256.000000                  NaN
#
#        teams.home.team.name     venue.id           venue.link     venue.name
# count                 11529  6311.000000                11529          11529
# unique                   62          NaN                   49            127
# top     Pittsburgh Penguins          NaN  /api/v1/venues/null  United Center
# freq                    418          NaN                 5218            410
# mean                    NaN  5055.555221                  NaN            NaN
# std                     NaN   138.584403                  NaN            NaN
# min                     NaN     3.000000                  NaN            NaN
# 25%                     NaN  5046.000000                  NaN            NaN
# 50%                     NaN  5064.000000                  NaN            NaN
# 75%                     NaN  5081.000000                  NaN            NaN
# max                     NaN  5260.000000                  NaN            NaN

# %%
gamesdf.columns
# Out:
# Index(['Unnamed: 0', 'away.teamStats.teamSkaterStats.blocked',
#        'away.teamStats.teamSkaterStats.faceOffWinPercentage',
#        'away.teamStats.teamSkaterStats.giveaways',
#        'away.teamStats.teamSkaterStats.goals',
#        'away.teamStats.teamSkaterStats.hits',
#        'away.teamStats.teamSkaterStats.pim',
#        'away.teamStats.teamSkaterStats.powerPlayGoals',
#        'away.teamStats.teamSkaterStats.powerPlayOpportunities',
#        'away.teamStats.teamSkaterStats.powerPlayPercentage',
#        'away.teamStats.teamSkaterStats.shots',
#        'away.teamStats.teamSkaterStats.takeaways', 'content.link', 'date',
#        'gameDate', 'gameID', 'gamePk', 'gameType',
#        'home.teamStats.teamSkaterStats.blocked',
#        'home.teamStats.teamSkaterStats.faceOffWinPercentage',
#        'home.teamStats.teamSkaterStats.giveaways',
#        'home.teamStats.teamSkaterStats.goals',
#        'home.teamStats.teamSkaterStats.hits',
#        'home.teamStats.teamSkaterStats.pim',
#        'home.teamStats.teamSkaterStats.powerPlayGoals',
#        'home.teamStats.teamSkaterStats.powerPlayOpportunities',
#        'home.teamStats.teamSkaterStats.powerPlayPercentage',
#        'home.teamStats.teamSkaterStats.shots',
#        'home.teamStats.teamSkaterStats.takeaways', 'link', 'season',
#        'status.abstractGameState', 'status.codedGameState',
#        'status.detailedState', 'status.startTimeTBD', 'status.statusCode',
#        'teams.away.leagueRecord.losses', 'teams.away.leagueRecord.ot',
#        'teams.away.leagueRecord.type', 'teams.away.leagueRecord.wins',
#        'teams.away.score', 'teams.away.team.id', 'teams.away.team.link',
#        'teams.away.team.name', 'teams.home.leagueRecord.losses',
#        'teams.home.leagueRecord.ot', 'teams.home.leagueRecord.type',
#        'teams.home.leagueRecord.wins', 'teams.home.score',
#        'teams.home.team.id', 'teams.home.team.link', 'teams.home.team.name',
#        'venue.id', 'venue.link', 'venue.name'],
#       dtype='object')

# %%
# List des features

features5L = ['away.teamStats.teamSkaterStats.blocked','away.teamStats.teamSkaterStats.faceOffWinPercentage',
              'away.teamStats.teamSkaterStats.giveaways','away.teamStats.teamSkaterStats.goals',
              'away.teamStats.teamSkaterStats.hits','away.teamStats.teamSkaterStats.pim',
              'away.teamStats.teamSkaterStats.powerPlayGoals','away.teamStats.teamSkaterStats.powerPlayOpportunities',
              'away.teamStats.teamSkaterStats.powerPlayPercentage','away.teamStats.teamSkaterStats.shots',
              'away.teamStats.teamSkaterStats.takeaways','home.teamStats.teamSkaterStats.blocked',
              'home.teamStats.teamSkaterStats.faceOffWinPercentage','home.teamStats.teamSkaterStats.giveaways',
              'home.teamStats.teamSkaterStats.goals','home.teamStats.teamSkaterStats.hits',
              'home.teamStats.teamSkaterStats.pim','home.teamStats.teamSkaterStats.powerPlayGoals',
              'home.teamStats.teamSkaterStats.powerPlayOpportunities','home.teamStats.teamSkaterStats.powerPlayPercentage',
              'home.teamStats.teamSkaterStats.shots','home.teamStats.teamSkaterStats.takeaways']

features1L = ['teams.away.leagueRecord.losses','teams.away.leagueRecord.ot',
              'teams.away.leagueRecord.wins','teams.home.leagueRecord.losses',
              'teams.home.leagueRecord.ot','teams.home.leagueRecord.wins']

#Variables date, saisons et equipes
state_time = ['teams.home.team.name', 'season', 'gamePk']

# %% [markdown]
# #### Create columns

# %%
# home win 

gamesdf['game.homewin'] = (gamesdf['teams.home.score'] - gamesdf['teams.away.score']> 0).astype('int')

# Keep relevent features and game.homewin
gamesdf['teams.home.leagueRecord.gameplayed'] = gamesdf['teams.home.leagueRecord.losses'] + gamesdf['teams.home.leagueRecord.wins'] + gamesdf['teams.home.leagueRecord.ot']
gamesdf['teams.away.leagueRecord.gameplayed'] = gamesdf['teams.away.leagueRecord.losses'] + gamesdf['teams.away.leagueRecord.wins'] + gamesdf['teams.away.leagueRecord.ot']

gamesdf = gamesdf[['game.homewin','teams.away.team.name','teams.home.leagueRecord.gameplayed','gameType','teams.away.leagueRecord.gameplayed'] + features5L + features1L + state_time]

# Create lags for features with only 1 lag
gamesdf = create_lag(df=gamesdf,
                      p=1,
                      sortList=['teams.home.team.name', 'season', 'gamePk'],
                      partList=['teams.home.team.name', 'season'],
                      lagList=features1L)

# Create lags for features with 5 lags
gamesdf = create_lag(df=gamesdf,
                      p=10,
                      sortList=['teams.home.team.name', 'season', 'gamePk'],
                      partList=['teams.home.team.name', 'season'],
                      lagList=features5L)

# Drop features that are not lagged
gamesdf = gamesdf.drop(columns=['gamePk'] + features1L + features5L)

# team away
gamesdf['teams.away.leagueRecord.gameplayed.L1'] = gamesdf['teams.away.leagueRecord.losses.L1'] + gamesdf['teams.away.leagueRecord.wins.L1'] + gamesdf['teams.away.leagueRecord.ot.L1']
# team home
gamesdf['teams.home.leagueRecord.gameplayed.L1'] = gamesdf['teams.home.leagueRecord.losses.L1'] + gamesdf['teams.home.leagueRecord.wins.L1'] + gamesdf['teams.home.leagueRecord.ot.L1']



# Nombre de points = ot + wins * 2

# team away
gamesdf['teams.away.leagueRecord.points.L1'] = (gamesdf['teams.away.leagueRecord.wins.L1'] * 2 ) + gamesdf['teams.away.leagueRecord.ot.L1']
# team home
gamesdf['teams.home.leagueRecord.points.L1'] = (gamesdf['teams.home.leagueRecord.wins.L1'] * 2 ) + gamesdf['teams.home.leagueRecord.ot.L1']



# Points Per Game = points / gp

# team away
gamesdf['teams.away.leagueRecord.ppg.L1'] = gamesdf['teams.away.leagueRecord.points.L1'] / gamesdf['teams.away.leagueRecord.gameplayed.L1']
# team home
gamesdf['teams.home.leagueRecord.ppg.L1'] = gamesdf['teams.home.leagueRecord.points.L1'] / gamesdf['teams.home.leagueRecord.gameplayed.L1']



# Difference PPG entre Home vs Away = home PPG - away PPG

gamesdf['game.ppgdiff_home.L1'] = gamesdf['teams.home.leagueRecord.ppg.L1'] - gamesdf['teams.away.leagueRecord.ppg.L1']

# %% [markdown]
# #### Clean data

# %%
# only Regular season matches ('A'= Allstar , 'P' = PostSeason, 'PR' = PreSeason)
gamesdf = gamesdf[gamesdf['gameType'] == 'R']

# there are some games with no data
#gamesdf.dropna(subset = ['game.ppgdiff_home'], inplace = True)

# only take games between the 15th and the 70 th game of the seasion
# Should we do the same thing for the away team ?
gamesdf = gamesdf[gamesdf['teams.home.leagueRecord.gameplayed'].between(15,70)]

# %%
gamesdf.head()
# Out:
#      game.homewin teams.away.team.name  teams.home.leagueRecord.gameplayed  \
# 206             0         Dallas Stars                                16.0
# 216             0      Phoenix Coyotes                                17.0
# 230             1      San Jose Sharks                                18.0
# 253             1    Los Angeles Kings                                19.0
# 315             0      Phoenix Coyotes                                23.0
#
#     gameType  teams.away.leagueRecord.gameplayed teams.home.team.name  \
# 206        R                                14.0        Anaheim Ducks
# 216        R                                13.0        Anaheim Ducks
# 230        R                                16.0        Anaheim Ducks
# 253        R                                17.0        Anaheim Ducks
# 315        R                                20.0        Anaheim Ducks
#
#        season  teams.away.leagueRecord.losses.L1  \
# 206  20072008                                3.0
# 216  20072008                                6.0
# 230  20072008                                7.0
# 253  20072008                                7.0
# 315  20072008                                8.0
#
#      teams.away.leagueRecord.ot.L1  teams.away.leagueRecord.wins.L1  \
# 206                            2.0                              7.0
# 216                            2.0                              6.0
# 230                            0.0                              6.0
# 253                            2.0                              7.0
# 315                            1.0                              8.0
#
#      teams.home.leagueRecord.losses.L1  teams.home.leagueRecord.ot.L1  \
# 206                                7.0                            2.0
# 216                                8.0                            2.0
# 230                                8.0                            3.0
# 253                                8.0                            3.0
# 315                                8.0                            3.0
#
#      teams.home.leagueRecord.wins.L1  \
# 206                              5.0
# 216                              6.0
# 230                              6.0
# 253                              7.0
# 315                              8.0
#
#      away.teamStats.teamSkaterStats.blocked.L1  \
# 206                                       13.0
# 216                                        4.0
# 230                                        8.0
# 253                                       11.0
# 315                                        5.0
#
#      away.teamStats.teamSkaterStats.blocked.L2  \
# 206                                        8.0
# 216                                       13.0
# 230                                        4.0
# 253                                        8.0
# 315                                       11.0
#
#      away.teamStats.teamSkaterStats.blocked.L3  \
# 206                                       17.0
# 216                                        8.0
# 230                                       13.0
# 253                                        4.0
# 315                                        8.0
#
#      away.teamStats.teamSkaterStats.blocked.L4  \
# 206                                        8.0
# 216                                       17.0
# 230                                        8.0
# 253                                       13.0
# 315                                        4.0
#
#      away.teamStats.teamSkaterStats.blocked.L5  \
# 206                                        5.0
# 216                                        8.0
# 230                                       17.0
# 253                                        8.0
# 315                                       13.0
#
#      away.teamStats.teamSkaterStats.blocked.L6  \
# 206                                       10.0
# 216                                        5.0
# 230                                        8.0
# 253                                       17.0
# 315                                        8.0
#
#      away.teamStats.teamSkaterStats.blocked.L7  \
# 206                                       12.0
# 216                                       10.0
# 230                                        5.0
# 253                                        8.0
# 315                                       17.0
#
#      away.teamStats.teamSkaterStats.blocked.L8  \
# 206                                        NaN
# 216                                       12.0
# 230                                       10.0
# 253                                        5.0
# 315                                        8.0
#
#      away.teamStats.teamSkaterStats.blocked.L9  \
# 206                                        NaN
# 216                                        NaN
# 230                                       12.0
# 253                                       10.0
# 315                                        5.0
#
#      away.teamStats.teamSkaterStats.blocked.L10  \
# 206                                         NaN
# 216                                         NaN
# 230                                         NaN
# 253                                        12.0
# 315                                        10.0
#
#      away.teamStats.teamSkaterStats.faceOffWinPercentage.L1  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                NaN
# 315                                                NaN
#
#      away.teamStats.teamSkaterStats.faceOffWinPercentage.L2  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                NaN
# 315                                                NaN
#
#      away.teamStats.teamSkaterStats.faceOffWinPercentage.L3  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                NaN
# 315                                                NaN
#
#      away.teamStats.teamSkaterStats.faceOffWinPercentage.L4  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                NaN
# 315                                                NaN
#
#      away.teamStats.teamSkaterStats.faceOffWinPercentage.L5  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                NaN
# 315                                                NaN
#
#      away.teamStats.teamSkaterStats.faceOffWinPercentage.L6  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                NaN
# 315                                                NaN
#
#      away.teamStats.teamSkaterStats.faceOffWinPercentage.L7  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                NaN
# 315                                                NaN
#
#      away.teamStats.teamSkaterStats.faceOffWinPercentage.L8  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                NaN
# 315                                                NaN
#
#      away.teamStats.teamSkaterStats.faceOffWinPercentage.L9  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                NaN
# 315                                                NaN
#
#      away.teamStats.teamSkaterStats.faceOffWinPercentage.L10  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                NaN
# 315                                                NaN
#
#      away.teamStats.teamSkaterStats.giveaways.L1  \
# 206                                          8.0
# 216                                          7.0
# 230                                          4.0
# 253                                          5.0
# 315                                         13.0
#
#      away.teamStats.teamSkaterStats.giveaways.L2  \
# 206                                          3.0
# 216                                          8.0
# 230                                          7.0
# 253                                          4.0
# 315                                          5.0
#
#      away.teamStats.teamSkaterStats.giveaways.L3  \
# 206                                          9.0
# 216                                          3.0
# 230                                          8.0
# 253                                          7.0
# 315                                          4.0
#
#      away.teamStats.teamSkaterStats.giveaways.L4  \
# 206                                          6.0
# 216                                          9.0
# 230                                          3.0
# 253                                          8.0
# 315                                          7.0
#
#      away.teamStats.teamSkaterStats.giveaways.L5  \
# 206                                          4.0
# 216                                          6.0
# 230                                          9.0
# 253                                          3.0
# 315                                          8.0
#
#      away.teamStats.teamSkaterStats.giveaways.L6  \
# 206                                          1.0
# 216                                          4.0
# 230                                          6.0
# 253                                          9.0
# 315                                          3.0
#
#      away.teamStats.teamSkaterStats.giveaways.L7  \
# 206                                         10.0
# 216                                          1.0
# 230                                          4.0
# 253                                          6.0
# 315                                          9.0
#
#      away.teamStats.teamSkaterStats.giveaways.L8  \
# 206                                          NaN
# 216                                         10.0
# 230                                          1.0
# 253                                          4.0
# 315                                          6.0
#
#      away.teamStats.teamSkaterStats.giveaways.L9  \
# 206                                          NaN
# 216                                          NaN
# 230                                         10.0
# 253                                          1.0
# 315                                          4.0
#
#      away.teamStats.teamSkaterStats.giveaways.L10  \
# 206                                           NaN
# 216                                           NaN
# 230                                           NaN
# 253                                          10.0
# 315                                           1.0
#
#      away.teamStats.teamSkaterStats.goals.L1  \
# 206                                      1.0
# 216                                      5.0
# 230                                      6.0
# 253                                      2.0
# 315                                      3.0
#
#      away.teamStats.teamSkaterStats.goals.L2  \
# 206                                      2.0
# 216                                      1.0
# 230                                      5.0
# 253                                      6.0
# 315                                      2.0
#
#      away.teamStats.teamSkaterStats.goals.L3  \
# 206                                      1.0
# 216                                      2.0
# 230                                      1.0
# 253                                      5.0
# 315                                      6.0
#
#      away.teamStats.teamSkaterStats.goals.L4  \
# 206                                      1.0
# 216                                      1.0
# 230                                      2.0
# 253                                      1.0
# 315                                      5.0
#
#      away.teamStats.teamSkaterStats.goals.L5  \
# 206                                      3.0
# 216                                      1.0
# 230                                      1.0
# 253                                      2.0
# 315                                      1.0
#
#      away.teamStats.teamSkaterStats.goals.L6  \
# 206                                      2.0
# 216                                      3.0
# 230                                      1.0
# 253                                      1.0
# 315                                      2.0
#
#      away.teamStats.teamSkaterStats.goals.L7  \
# 206                                      1.0
# 216                                      2.0
# 230                                      3.0
# 253                                      1.0
# 315                                      1.0
#
#      away.teamStats.teamSkaterStats.goals.L8  \
# 206                                      NaN
# 216                                      1.0
# 230                                      2.0
# 253                                      3.0
# 315                                      1.0
#
#      away.teamStats.teamSkaterStats.goals.L9  \
# 206                                      NaN
# 216                                      NaN
# 230                                      1.0
# 253                                      2.0
# 315                                      3.0
#
#      away.teamStats.teamSkaterStats.goals.L10  \
# 206                                       NaN
# 216                                       NaN
# 230                                       NaN
# 253                                       1.0
# 315                                       2.0
#
#      away.teamStats.teamSkaterStats.hits.L1  \
# 206                                    18.0
# 216                                     9.0
# 230                                    11.0
# 253                                    14.0
# 315                                     9.0
#
#      away.teamStats.teamSkaterStats.hits.L2  \
# 206                                    11.0
# 216                                    18.0
# 230                                     9.0
# 253                                    11.0
# 315                                    14.0
#
#      away.teamStats.teamSkaterStats.hits.L3  \
# 206                                    12.0
# 216                                    11.0
# 230                                    18.0
# 253                                     9.0
# 315                                    11.0
#
#      away.teamStats.teamSkaterStats.hits.L4  \
# 206                                    14.0
# 216                                    12.0
# 230                                    11.0
# 253                                    18.0
# 315                                     9.0
#
#      away.teamStats.teamSkaterStats.hits.L5  \
# 206                                    11.0
# 216                                    14.0
# 230                                    12.0
# 253                                    11.0
# 315                                    18.0
#
#      away.teamStats.teamSkaterStats.hits.L6  \
# 206                                     6.0
# 216                                    11.0
# 230                                    14.0
# 253                                    12.0
# 315                                    11.0
#
#      away.teamStats.teamSkaterStats.hits.L7  \
# 206                                    14.0
# 216                                     6.0
# 230                                    11.0
# 253                                    14.0
# 315                                    12.0
#
#      away.teamStats.teamSkaterStats.hits.L8  \
# 206                                     NaN
# 216                                    14.0
# 230                                     6.0
# 253                                    11.0
# 315                                    14.0
#
#      away.teamStats.teamSkaterStats.hits.L9  \
# 206                                     NaN
# 216                                     NaN
# 230                                    14.0
# 253                                     6.0
# 315                                    11.0
#
#      away.teamStats.teamSkaterStats.hits.L10  \
# 206                                      NaN
# 216                                      NaN
# 230                                      NaN
# 253                                     14.0
# 315                                      6.0
#
#      away.teamStats.teamSkaterStats.pim.L1  \
# 206                                   39.0
# 216                                   17.0
# 230                                   12.0
# 253                                    2.0
# 315                                   25.0
#
#      away.teamStats.teamSkaterStats.pim.L2  \
# 206                                    6.0
# 216                                   39.0
# 230                                   17.0
# 253                                   12.0
# 315                                    2.0
#
#      away.teamStats.teamSkaterStats.pim.L3  \
# 206                                   12.0
# 216                                    6.0
# 230                                   39.0
# 253                                   17.0
# 315                                   12.0
#
#      away.teamStats.teamSkaterStats.pim.L4  \
# 206                                    9.0
# 216                                   12.0
# 230                                    6.0
# 253                                   39.0
# 315                                   17.0
#
#      away.teamStats.teamSkaterStats.pim.L5  \
# 206                                   26.0
# 216                                    9.0
# 230                                   12.0
# 253                                    6.0
# 315                                   39.0
#
#      away.teamStats.teamSkaterStats.pim.L6  \
# 206                                   33.0
# 216                                   26.0
# 230                                    9.0
# 253                                   12.0
# 315                                    6.0
#
#      away.teamStats.teamSkaterStats.pim.L7  \
# 206                                    6.0
# 216                                   33.0
# 230                                   26.0
# 253                                    9.0
# 315                                   12.0
#
#      away.teamStats.teamSkaterStats.pim.L8  \
# 206                                    NaN
# 216                                    6.0
# 230                                   33.0
# 253                                   26.0
# 315                                    9.0
#
#      away.teamStats.teamSkaterStats.pim.L9  \
# 206                                    NaN
# 216                                    NaN
# 230                                    6.0
# 253                                   33.0
# 315                                   26.0
#
#      away.teamStats.teamSkaterStats.pim.L10  \
# 206                                     NaN
# 216                                     NaN
# 230                                     NaN
# 253                                     6.0
# 315                                    33.0
#
#      away.teamStats.teamSkaterStats.powerPlayGoals.L1  \
# 206                                               1.0
# 216                                               2.0
# 230                                               2.0
# 253                                               1.0
# 315                                               2.0
#
#      away.teamStats.teamSkaterStats.powerPlayGoals.L2  \
# 206                                               0.0
# 216                                               1.0
# 230                                               2.0
# 253                                               2.0
# 315                                               1.0
#
#      away.teamStats.teamSkaterStats.powerPlayGoals.L3  \
# 206                                               0.0
# 216                                               0.0
# 230                                               1.0
# 253                                               2.0
# 315                                               2.0
#
#      away.teamStats.teamSkaterStats.powerPlayGoals.L4  \
# 206                                               0.0
# 216                                               0.0
# 230                                               0.0
# 253                                               1.0
# 315                                               2.0
#
#      away.teamStats.teamSkaterStats.powerPlayGoals.L5  \
# 206                                               1.0
# 216                                               0.0
# 230                                               0.0
# 253                                               0.0
# 315                                               1.0
#
#      away.teamStats.teamSkaterStats.powerPlayGoals.L6  \
# 206                                               0.0
# 216                                               1.0
# 230                                               0.0
# 253                                               0.0
# 315                                               0.0
#
#      away.teamStats.teamSkaterStats.powerPlayGoals.L7  \
# 206                                               0.0
# 216                                               0.0
# 230                                               1.0
# 253                                               0.0
# 315                                               0.0
#
#      away.teamStats.teamSkaterStats.powerPlayGoals.L8  \
# 206                                               NaN
# 216                                               0.0
# 230                                               0.0
# 253                                               1.0
# 315                                               0.0
#
#      away.teamStats.teamSkaterStats.powerPlayGoals.L9  \
# 206                                               NaN
# 216                                               NaN
# 230                                               0.0
# 253                                               0.0
# 315                                               1.0
#
#      away.teamStats.teamSkaterStats.powerPlayGoals.L10  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                0.0
# 315                                                0.0
#
#      away.teamStats.teamSkaterStats.powerPlayOpportunities.L1  \
# 206                                                6.0
# 216                                                3.0
# 230                                                7.0
# 253                                                6.0
# 315                                                8.0
#
#      away.teamStats.teamSkaterStats.powerPlayOpportunities.L2  \
# 206                                                4.0
# 216                                                6.0
# 230                                                3.0
# 253                                                7.0
# 315                                                6.0
#
#      away.teamStats.teamSkaterStats.powerPlayOpportunities.L3  \
# 206                                                5.0
# 216                                                4.0
# 230                                                6.0
# 253                                                3.0
# 315                                                7.0
#
#      away.teamStats.teamSkaterStats.powerPlayOpportunities.L4  \
# 206                                                2.0
# 216                                                5.0
# 230                                                4.0
# 253                                                6.0
# 315                                                3.0
#
#      away.teamStats.teamSkaterStats.powerPlayOpportunities.L5  \
# 206                                                9.0
# 216                                                2.0
# 230                                                5.0
# 253                                                4.0
# 315                                                6.0
#
#      away.teamStats.teamSkaterStats.powerPlayOpportunities.L6  \
# 206                                                4.0
# 216                                                9.0
# 230                                                2.0
# 253                                                5.0
# 315                                                4.0
#
#      away.teamStats.teamSkaterStats.powerPlayOpportunities.L7  \
# 206                                                3.0
# 216                                                4.0
# 230                                                9.0
# 253                                                2.0
# 315                                                5.0
#
#      away.teamStats.teamSkaterStats.powerPlayOpportunities.L8  \
# 206                                                NaN
# 216                                                3.0
# 230                                                4.0
# 253                                                9.0
# 315                                                2.0
#
#      away.teamStats.teamSkaterStats.powerPlayOpportunities.L9  \
# 206                                                NaN
# 216                                                NaN
# 230                                                3.0
# 253                                                4.0
# 315                                                9.0
#
#      away.teamStats.teamSkaterStats.powerPlayOpportunities.L10  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                3.0
# 315                                                4.0
#
#      away.teamStats.teamSkaterStats.powerPlayPercentage.L1  \
# 206                                               16.7
# 216                                               66.7
# 230                                               28.6
# 253                                               16.7
# 315                                               25.0
#
#      away.teamStats.teamSkaterStats.powerPlayPercentage.L2  \
# 206                                                0.0
# 216                                               16.7
# 230                                               66.7
# 253                                               28.6
# 315                                               16.7
#
#      away.teamStats.teamSkaterStats.powerPlayPercentage.L3  \
# 206                                                0.0
# 216                                                0.0
# 230                                               16.7
# 253                                               66.7
# 315                                               28.6
#
#      away.teamStats.teamSkaterStats.powerPlayPercentage.L4  \
# 206                                                0.0
# 216                                                0.0
# 230                                                0.0
# 253                                               16.7
# 315                                               66.7
#
#      away.teamStats.teamSkaterStats.powerPlayPercentage.L5  \
# 206                                               11.1
# 216                                                0.0
# 230                                                0.0
# 253                                                0.0
# 315                                               16.7
#
#      away.teamStats.teamSkaterStats.powerPlayPercentage.L6  \
# 206                                                0.0
# 216                                               11.1
# 230                                                0.0
# 253                                                0.0
# 315                                                0.0
#
#      away.teamStats.teamSkaterStats.powerPlayPercentage.L7  \
# 206                                                0.0
# 216                                                0.0
# 230                                               11.1
# 253                                                0.0
# 315                                                0.0
#
#      away.teamStats.teamSkaterStats.powerPlayPercentage.L8  \
# 206                                                NaN
# 216                                                0.0
# 230                                                0.0
# 253                                               11.1
# 315                                                0.0
#
#      away.teamStats.teamSkaterStats.powerPlayPercentage.L9  \
# 206                                                NaN
# 216                                                NaN
# 230                                                0.0
# 253                                                0.0
# 315                                               11.1
#
#      away.teamStats.teamSkaterStats.powerPlayPercentage.L10  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                0.0
# 315                                                0.0
#
#      away.teamStats.teamSkaterStats.shots.L1  \
# 206                                     20.0
# 216                                     24.0
# 230                                     29.0
# 253                                     24.0
# 315                                     32.0
#
#      away.teamStats.teamSkaterStats.shots.L2  \
# 206                                     22.0
# 216                                     20.0
# 230                                     24.0
# 253                                     29.0
# 315                                     24.0
#
#      away.teamStats.teamSkaterStats.shots.L3  \
# 206                                     21.0
# 216                                     22.0
# 230                                     20.0
# 253                                     24.0
# 315                                     29.0
#
#      away.teamStats.teamSkaterStats.shots.L4  \
# 206                                     29.0
# 216                                     21.0
# 230                                     22.0
# 253                                     20.0
# 315                                     24.0
#
#      away.teamStats.teamSkaterStats.shots.L5  \
# 206                                     35.0
# 216                                     29.0
# 230                                     21.0
# 253                                     22.0
# 315                                     20.0
#
#      away.teamStats.teamSkaterStats.shots.L6  \
# 206                                     25.0
# 216                                     35.0
# 230                                     29.0
# 253                                     21.0
# 315                                     22.0
#
#      away.teamStats.teamSkaterStats.shots.L7  \
# 206                                     19.0
# 216                                     25.0
# 230                                     35.0
# 253                                     29.0
# 315                                     21.0
#
#      away.teamStats.teamSkaterStats.shots.L8  \
# 206                                      NaN
# 216                                     19.0
# 230                                     25.0
# 253                                     35.0
# 315                                     29.0
#
#      away.teamStats.teamSkaterStats.shots.L9  \
# 206                                      NaN
# 216                                      NaN
# 230                                     19.0
# 253                                     25.0
# 315                                     35.0
#
#      away.teamStats.teamSkaterStats.shots.L10  \
# 206                                       NaN
# 216                                       NaN
# 230                                       NaN
# 253                                      19.0
# 315                                      25.0
#
#      away.teamStats.teamSkaterStats.takeaways.L1  \
# 206                                         10.0
# 216                                          6.0
# 230                                          4.0
# 253                                          4.0
# 315                                          6.0
#
#      away.teamStats.teamSkaterStats.takeaways.L2  \
# 206                                          3.0
# 216                                         10.0
# 230                                          6.0
# 253                                          4.0
# 315                                          4.0
#
#      away.teamStats.teamSkaterStats.takeaways.L3  \
# 206                                          8.0
# 216                                          3.0
# 230                                         10.0
# 253                                          6.0
# 315                                          4.0
#
#      away.teamStats.teamSkaterStats.takeaways.L4  \
# 206                                          8.0
# 216                                          8.0
# 230                                          3.0
# 253                                         10.0
# 315                                          6.0
#
#      away.teamStats.teamSkaterStats.takeaways.L5  \
# 206                                          8.0
# 216                                          8.0
# 230                                          8.0
# 253                                          3.0
# 315                                         10.0
#
#      away.teamStats.teamSkaterStats.takeaways.L6  \
# 206                                          3.0
# 216                                          8.0
# 230                                          8.0
# 253                                          8.0
# 315                                          3.0
#
#      away.teamStats.teamSkaterStats.takeaways.L7  \
# 206                                          6.0
# 216                                          3.0
# 230                                          8.0
# 253                                          8.0
# 315                                          8.0
#
#      away.teamStats.teamSkaterStats.takeaways.L8  \
# 206                                          NaN
# 216                                          6.0
# 230                                          3.0
# 253                                          8.0
# 315                                          8.0
#
#      away.teamStats.teamSkaterStats.takeaways.L9  \
# 206                                          NaN
# 216                                          NaN
# 230                                          6.0
# 253                                          3.0
# 315                                          8.0
#
#      away.teamStats.teamSkaterStats.takeaways.L10  \
# 206                                           NaN
# 216                                           NaN
# 230                                           NaN
# 253                                           6.0
# 315                                           3.0
#
#      home.teamStats.teamSkaterStats.blocked.L1  \
# 206                                        7.0
# 216                                        9.0
# 230                                        5.0
# 253                                       11.0
# 315                                        9.0
#
#      home.teamStats.teamSkaterStats.blocked.L2  \
# 206                                        4.0
# 216                                        7.0
# 230                                        9.0
# 253                                        5.0
# 315                                       11.0
#
#      home.teamStats.teamSkaterStats.blocked.L3  \
# 206                                        8.0
# 216                                        4.0
# 230                                        7.0
# 253                                        9.0
# 315                                        5.0
#
#      home.teamStats.teamSkaterStats.blocked.L4  \
# 206                                       12.0
# 216                                        8.0
# 230                                        4.0
# 253                                        7.0
# 315                                        9.0
#
#      home.teamStats.teamSkaterStats.blocked.L5  \
# 206                                       11.0
# 216                                       12.0
# 230                                        8.0
# 253                                        4.0
# 315                                        7.0
#
#      home.teamStats.teamSkaterStats.blocked.L6  \
# 206                                        7.0
# 216                                       11.0
# 230                                       12.0
# 253                                        8.0
# 315                                        4.0
#
#      home.teamStats.teamSkaterStats.blocked.L7  \
# 206                                        5.0
# 216                                        7.0
# 230                                       11.0
# 253                                       12.0
# 315                                        8.0
#
#      home.teamStats.teamSkaterStats.blocked.L8  \
# 206                                        NaN
# 216                                        5.0
# 230                                        7.0
# 253                                       11.0
# 315                                       12.0
#
#      home.teamStats.teamSkaterStats.blocked.L9  \
# 206                                        NaN
# 216                                        NaN
# 230                                        5.0
# 253                                        7.0
# 315                                       11.0
#
#      home.teamStats.teamSkaterStats.blocked.L10  \
# 206                                         NaN
# 216                                         NaN
# 230                                         NaN
# 253                                         5.0
# 315                                         7.0
#
#      home.teamStats.teamSkaterStats.faceOffWinPercentage.L1  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                NaN
# 315                                                NaN
#
#      home.teamStats.teamSkaterStats.faceOffWinPercentage.L2  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                NaN
# 315                                                NaN
#
#      home.teamStats.teamSkaterStats.faceOffWinPercentage.L3  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                NaN
# 315                                                NaN
#
#      home.teamStats.teamSkaterStats.faceOffWinPercentage.L4  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                NaN
# 315                                                NaN
#
#      home.teamStats.teamSkaterStats.faceOffWinPercentage.L5  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                NaN
# 315                                                NaN
#
#      home.teamStats.teamSkaterStats.faceOffWinPercentage.L6  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                NaN
# 315                                                NaN
#
#      home.teamStats.teamSkaterStats.faceOffWinPercentage.L7  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                NaN
# 315                                                NaN
#
#      home.teamStats.teamSkaterStats.faceOffWinPercentage.L8  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                NaN
# 315                                                NaN
#
#      home.teamStats.teamSkaterStats.faceOffWinPercentage.L9  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                NaN
# 315                                                NaN
#
#      home.teamStats.teamSkaterStats.faceOffWinPercentage.L10  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                NaN
# 315                                                NaN
#
#      home.teamStats.teamSkaterStats.giveaways.L1  \
# 206                                         15.0
# 216                                          7.0
# 230                                          8.0
# 253                                         11.0
# 315                                          8.0
#
#      home.teamStats.teamSkaterStats.giveaways.L2  \
# 206                                          9.0
# 216                                         15.0
# 230                                          7.0
# 253                                          8.0
# 315                                         11.0
#
#      home.teamStats.teamSkaterStats.giveaways.L3  \
# 206                                         11.0
# 216                                          9.0
# 230                                         15.0
# 253                                          7.0
# 315                                          8.0
#
#      home.teamStats.teamSkaterStats.giveaways.L4  \
# 206                                          9.0
# 216                                         11.0
# 230                                          9.0
# 253                                         15.0
# 315                                          7.0
#
#      home.teamStats.teamSkaterStats.giveaways.L5  \
# 206                                          9.0
# 216                                          9.0
# 230                                         11.0
# 253                                          9.0
# 315                                         15.0
#
#      home.teamStats.teamSkaterStats.giveaways.L6  \
# 206                                         12.0
# 216                                          9.0
# 230                                          9.0
# 253                                         11.0
# 315                                          9.0
#
#      home.teamStats.teamSkaterStats.giveaways.L7  \
# 206                                          6.0
# 216                                         12.0
# 230                                          9.0
# 253                                          9.0
# 315                                         11.0
#
#      home.teamStats.teamSkaterStats.giveaways.L8  \
# 206                                          NaN
# 216                                          6.0
# 230                                         12.0
# 253                                          9.0
# 315                                          9.0
#
#      home.teamStats.teamSkaterStats.giveaways.L9  \
# 206                                          NaN
# 216                                          NaN
# 230                                          6.0
# 253                                         12.0
# 315                                          9.0
#
#      home.teamStats.teamSkaterStats.giveaways.L10  \
# 206                                           NaN
# 216                                           NaN
# 230                                           NaN
# 253                                           6.0
# 315                                          12.0
#
#      home.teamStats.teamSkaterStats.goals.L1  \
# 206                                      1.0
# 216                                      0.0
# ...
#
#      home.teamStats.teamSkaterStats.powerPlayGoals.L9  \
# 206                                               NaN
# 216                                               NaN
# 230                                               0.0
# 253                                               0.0
# 315                                               2.0
#
#      home.teamStats.teamSkaterStats.powerPlayGoals.L10  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                0.0
# 315                                                0.0
#
#      home.teamStats.teamSkaterStats.powerPlayOpportunities.L1  \
# 206                                                6.0
# 216                                                4.0
# 230                                                5.0
# 253                                                1.0
# 315                                                4.0
#
#      home.teamStats.teamSkaterStats.powerPlayOpportunities.L2  \
# 206                                                3.0
# 216                                                6.0
# 230                                                4.0
# 253                                                5.0
# 315                                                1.0
#
#      home.teamStats.teamSkaterStats.powerPlayOpportunities.L3  \
# 206                                                6.0
# 216                                                3.0
# 230                                                6.0
# 253                                                4.0
# 315                                                5.0
#
#      home.teamStats.teamSkaterStats.powerPlayOpportunities.L4  \
# 206                                                2.0
# 216                                                6.0
# 230                                                3.0
# 253                                                6.0
# 315                                                4.0
#
#      home.teamStats.teamSkaterStats.powerPlayOpportunities.L5  \
# 206                                               11.0
# 216                                                2.0
# 230                                                6.0
# 253                                                3.0
# 315                                                6.0
#
#      home.teamStats.teamSkaterStats.powerPlayOpportunities.L6  \
# 206                                                8.0
# 216                                               11.0
# 230                                                2.0
# 253                                                6.0
# 315                                                3.0
#
#      home.teamStats.teamSkaterStats.powerPlayOpportunities.L7  \
# 206                                                3.0
# 216                                                8.0
# 230                                               11.0
# 253                                                2.0
# 315                                                6.0
#
#      home.teamStats.teamSkaterStats.powerPlayOpportunities.L8  \
# 206                                                NaN
# 216                                                3.0
# 230                                                8.0
# 253                                               11.0
# 315                                                2.0
#
#      home.teamStats.teamSkaterStats.powerPlayOpportunities.L9  \
# 206                                                NaN
# 216                                                NaN
# 230                                                3.0
# 253                                                8.0
# 315                                               11.0
#
#      home.teamStats.teamSkaterStats.powerPlayOpportunities.L10  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                3.0
# 315                                                8.0
#
#      home.teamStats.teamSkaterStats.powerPlayPercentage.L1  \
# 206                                                0.0
# 216                                                0.0
# 230                                               40.0
# 253                                                0.0
# 315                                               50.0
#
#      home.teamStats.teamSkaterStats.powerPlayPercentage.L2  \
# 206                                                0.0
# 216                                                0.0
# 230                                                0.0
# 253                                               40.0
# 315                                                0.0
#
#      home.teamStats.teamSkaterStats.powerPlayPercentage.L3  \
# 206                                                0.0
# 216                                                0.0
# 230                                                0.0
# 253                                                0.0
# 315                                               40.0
#
#      home.teamStats.teamSkaterStats.powerPlayPercentage.L4  \
# 206                                                0.0
# 216                                                0.0
# 230                                                0.0
# 253                                                0.0
# 315                                                0.0
#
#      home.teamStats.teamSkaterStats.powerPlayPercentage.L5  \
# 206                                               18.2
# 216                                                0.0
# 230                                                0.0
# 253                                                0.0
# 315                                                0.0
#
#      home.teamStats.teamSkaterStats.powerPlayPercentage.L6  \
# 206                                                0.0
# 216                                               18.2
# 230                                                0.0
# 253                                                0.0
# 315                                                0.0
#
#      home.teamStats.teamSkaterStats.powerPlayPercentage.L7  \
# 206                                                0.0
# 216                                                0.0
# 230                                               18.2
# 253                                                0.0
# 315                                                0.0
#
#      home.teamStats.teamSkaterStats.powerPlayPercentage.L8  \
# 206                                                NaN
# 216                                                0.0
# 230                                                0.0
# 253                                               18.2
# 315                                                0.0
#
#      home.teamStats.teamSkaterStats.powerPlayPercentage.L9  \
# 206                                                NaN
# 216                                                NaN
# 230                                                0.0
# 253                                                0.0
# 315                                               18.2
#
#      home.teamStats.teamSkaterStats.powerPlayPercentage.L10  \
# 206                                                NaN
# 216                                                NaN
# 230                                                NaN
# 253                                                0.0
# 315                                                0.0
#
#      home.teamStats.teamSkaterStats.shots.L1  \
# 206                                     34.0
# 216                                     19.0
# 230                                     27.0
# 253                                     26.0
# 315                                     33.0
#
#      home.teamStats.teamSkaterStats.shots.L2  \
# 206                                     32.0
# 216                                     34.0
# 230                                     19.0
# 253                                     27.0
# 315                                     26.0
#
#      home.teamStats.teamSkaterStats.shots.L3  \
# 206                                     31.0
# 216                                     32.0
# 230                                     34.0
# 253                                     19.0
# 315                                     27.0
#
#      home.teamStats.teamSkaterStats.shots.L4  \
# 206                                     31.0
# 216                                     31.0
# 230                                     32.0
# 253                                     34.0
# 315                                     19.0
#
#      home.teamStats.teamSkaterStats.shots.L5  \
# 206                                     29.0
# 216                                     31.0
# 230                                     31.0
# 253                                     32.0
# 315                                     34.0
#
#      home.teamStats.teamSkaterStats.shots.L6  \
# 206                                     37.0
# 216                                     29.0
# 230                                     31.0
# 253                                     31.0
# 315                                     32.0
#
#      home.teamStats.teamSkaterStats.shots.L7  \
# 206                                     30.0
# 216                                     37.0
# 230                                     29.0
# 253                                     31.0
# 315                                     31.0
#
#      home.teamStats.teamSkaterStats.shots.L8  \
# 206                                      NaN
# 216                                     30.0
# 230                                     37.0
# 253                                     29.0
# 315                                     31.0
#
#      home.teamStats.teamSkaterStats.shots.L9  \
# 206                                      NaN
# 216                                      NaN
# 230                                     30.0
# 253                                     37.0
# 315                                     29.0
#
#      home.teamStats.teamSkaterStats.shots.L10  \
# 206                                       NaN
# 216                                       NaN
# 230                                       NaN
# 253                                      30.0
# 315                                      37.0
#
#      home.teamStats.teamSkaterStats.takeaways.L1  \
# 206                                          6.0
# 216                                          6.0
# 230                                          5.0
# 253                                          6.0
# 315                                          6.0
#
#      home.teamStats.teamSkaterStats.takeaways.L2  \
# 206                                         11.0
# 216                                          6.0
# 230                                          6.0
# 253                                          5.0
# 315                                          6.0
#
#      home.teamStats.teamSkaterStats.takeaways.L3  \
# 206                                          6.0
# 216                                         11.0
# 230                                          6.0
# 253                                          6.0
# 315                                          5.0
#
#      home.teamStats.teamSkaterStats.takeaways.L4  \
# 206                                          6.0
# 216                                          6.0
# 230                                         11.0
# 253                                          6.0
# 315                                          6.0
#
#      home.teamStats.teamSkaterStats.takeaways.L5  \
# 206                                         13.0
# 216                                          6.0
# 230                                          6.0
# 253                                         11.0
# 315                                          6.0
#
#      home.teamStats.teamSkaterStats.takeaways.L6  \
# 206                                          3.0
# 216                                         13.0
# 230                                          6.0
# 253                                          6.0
# 315                                         11.0
#
#      home.teamStats.teamSkaterStats.takeaways.L7  \
# 206                                          8.0
# 216                                          3.0
# 230                                         13.0
# 253                                          6.0
# 315                                          6.0
#
#      home.teamStats.teamSkaterStats.takeaways.L8  \
# 206                                          NaN
# 216                                          8.0
# 230                                          3.0
# 253                                         13.0
# 315                                          6.0
#
#      home.teamStats.teamSkaterStats.takeaways.L9  \
# 206                                          NaN
# 216                                          NaN
# 230                                          8.0
# 253                                          3.0
# 315                                         13.0
#
#      home.teamStats.teamSkaterStats.takeaways.L10  \
# 206                                           NaN
# 216                                           NaN
# 230                                           NaN
# 253                                           8.0
# 315                                           3.0
#
#      teams.away.leagueRecord.gameplayed.L1  \
# 206                                   12.0
# 216                                   14.0
# 230                                   13.0
# 253                                   16.0
# 315                                   17.0
#
#      teams.home.leagueRecord.gameplayed.L1  teams.away.leagueRecord.points.L1  \
# 206                                   14.0                               16.0
# 216                                   16.0                               14.0
# 230                                   17.0                               12.0
# 253                                   18.0                               16.0
# 315                                   19.0                               17.0
#
#      teams.home.leagueRecord.points.L1  teams.away.leagueRecord.ppg.L1  \
# 206                               12.0                        1.333333
# 216                               14.0                        1.000000
# 230                               15.0                        0.923077
# 253                               17.0                        1.000000
# 315                               19.0                        1.000000
#
#      teams.home.leagueRecord.ppg.L1  game.ppgdiff_home.L1
# 206                        0.857143             -0.476190
# 216                        0.875000             -0.125000
# 230                        0.882353             -0.040724
# 253                        0.944444             -0.055556
# 315                        1.000000              0.000000

# %%
gamesdf = gamesdf.dropna(axis=1)

# %%
# Save the data
gamesdf.to_csv('../../data/model_input.csv')
